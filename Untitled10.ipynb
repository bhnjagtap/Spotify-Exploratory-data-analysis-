# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/dataset.csv")

df.shape
# Out:
# (77911, 21)

# %%
df.head(5)
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
df.columns
df = df.drop("Unnamed: 0",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_458/3302322903.py in <cell line: 0>()
#       1 df.columns
# ----> 2 df = df.drop("Unnamed: 0",axis=1)
#       3 df.head(5)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
df.head(5)
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %%
df.dtypes
# Out:
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object

# %%
df.isna()
# Out:
#        track_id  artists  album_name  track_name  popularity  duration_ms  \
# 0         False    False       False       False       False        False
# 1         False    False       False       False       False        False
# 2         False    False       False       False       False        False
# 3         False    False       False       False       False        False
# 4         False    False       False       False       False        False
# ...         ...      ...         ...         ...         ...          ...
# 77906     False    False       False       False       False        False
# 77907     False    False       False       False       False        False
# 77908     False    False       False       False       False        False
# 77909     False    False       False       False       False        False
# 77910     False    False       False       False       False        False
#
#        explicit  danceability  energy    key  loudness   mode  speechiness  \
# 0         False         False   False  False     False  False        False
# 1         False         False   False  False     False  False        False
# 2         False         False   False  False     False  False        False
# 3         False         False   False  False     False  False        False
# 4         False         False   False  False     False  False        False
# ...         ...           ...     ...    ...       ...    ...          ...
# 77906     False         False   False  False     False  False        False
# 77907     False         False   False  False     False  False        False
# 77908     False         False   False  False     False  False        False
# 77909     False         False   False  False     False  False        False
# 77910     False         False   False  False     False  False        False
#
#        acousticness  instrumentalness  liveness  valence  tempo  \
# 0             False             False     False    False  False
# 1             False             False     False    False  False
# 2             False             False     False    False  False
# 3             False             False     False    False  False
# 4             False             False     False    False  False
# ...             ...               ...       ...      ...    ...
# 77906         False             False     False    False  False
# 77907         False             False     False    False  False
# 77908         False             False     False    False  False
# 77909         False             False     False    False  False
# 77910         False             False     False    False  False
#
#        time_signature  track_genre
# 0               False        False
# 1               False        False
# 2               False        False
# 3               False        False
# 4               False        False
# ...               ...          ...
# 77906           False        False
# 77907           False        False
# 77908           False        False
# 77909           False        False
# 77910           False         True
#
# [77911 rows x 20 columns]

# %%
df.isna().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         1
# dtype: int64

# %%
df.loc[df['artists'].isna()]
# Out:
#                      track_id artists album_name track_name  popularity  \
# 65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN           0
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 65900            0     False         0.501   0.583    7     -9.46     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature track_genre
# 65900  138.391               4       k-pop

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 77906    False
# 77907    False
# 77908    False
# 77909    False
# 77910    False
# Length: 77911, dtype: bool

# %%
df.duplicated(keep=False).sum()
# Out:
# np.int64(627)

# %%
df.loc[df.duplicated(keep=False)].sort_values('track_id')
# Out:
#                      track_id  \
# 52714  00JZ83w0Qm09f4PwWj06sM
# 52766  00JZ83w0Qm09f4PwWj06sM
# 39307  02KmEChUwcjxG3G29kbLFT
# 39275  02KmEChUwcjxG3G29kbLFT
# 16747  03B8ZXUmuDpf59j5PIMFHq
# ...                       ...
# 17891  7ykxRuzU1KhQC2TZ2YDEyK
# 52520  7zBY3YjvcdkpbHIUx0fe5Q
# 52570  7zBY3YjvcdkpbHIUx0fe5Q
# 16919  7zo05whm8LBnnt1dG979ov
# 16719  7zo05whm8LBnnt1dG979ov
#
#                                                  artists  \
# 52714                                       George Jones
# 52766                                       George Jones
# 39307  Hans Zimmer;Henning Lohner;Martin Tillman;Fiac...
# 39275  Hans Zimmer;Henning Lohner;Martin Tillman;Fiac...
# 16747  Wolfgang Amadeus Mozart;Heinz Holliger;Academy...
# ...                                                  ...
# 17891                                        Organ Tapes
# 52520                                      Hank Williams
# 52570                                      Hank Williams
# 16919  Wolfgang Amadeus Mozart;Wiener Mozart Ensemble...
# 16719  Wolfgang Amadeus Mozart;Wiener Mozart Ensemble...
#
#                                               album_name  \
# 52714                                          With Love
# 52766                                          With Love
# 39307                           Hans Zimmer: Epic Scores
# 39275                           Hans Zimmer: Epic Scores
# 16747                          Mozart - All Day Classics
# ...                                                  ...
# 17891  唱着那无人问津的歌谣 / Chang Zhe Na Wu Ren Wen Jin De Ge...
# 52520  Hank Williams As Luke The Drifter (Expanded Ed...
# 52570  Hank Williams As Luke The Drifter (Expanded Ed...
# 16919                          Mozart - A Classical Dawn
# 16719                          Mozart - A Classical Dawn
#
#                                               track_name  popularity  \
# 52714                          A Good Year For The Roses          12
# 52766                          A Good Year For The Roses          12
# 39307                                   Shelter Mountain          16
# 39275                                   Shelter Mountain          16
# 16747  Ma che vi fece... Sperai vicino, K.368: 1. And...           7
# ...                                                  ...         ...
# 17891                                                 ID          15
# 52520                                  Everything's Okay          12
# 52570                                  Everything's Okay          12
# 16919    Six German Dances, K.571: No. 5 in B Flat Major           3
# 16719    Six German Dances, K.571: No. 5 in B Flat Major           3
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 52714       190546     False         0.491   0.334   11    -9.684     1
# 52766       190546     False         0.491   0.334   11    -9.684     1
# 39307       250520     False         0.144   0.262    9   -21.228     1
# 39275       250520     False         0.144   0.262    9   -21.228     1
# 16747        86160     False         0.290   0.049    5   -24.072     1
# ...            ...       ...           ...     ...  ...       ...   ...
# 17891       203541     False         0.194   0.236    4   -13.885     0
# 52520       172026     False         0.607   0.378    7   -13.581     1
# 52570       172026     False         0.607   0.378    7   -13.581     1
# 16919        92000     False         0.539   0.158   10   -15.544     1
# 16719        92000     False         0.539   0.158   10   -15.544     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence   tempo  \
# 52714       0.0287         0.659          0.000016    0.1160   0.2490  91.674
# 52766       0.0287         0.659          0.000016    0.1160   0.2490  91.674
# 39307       0.0641         0.876          0.755000    0.1440   0.0345  94.430
# 39275       0.0641         0.876          0.755000    0.1440   0.0345  94.430
# 16747       0.0555         0.980          0.753000    0.1080   0.1140  76.473
# ...            ...           ...               ...       ...      ...     ...
# 17891       0.0353         0.271          0.027500    0.0833   0.0700  96.489
# 52520       0.1480         0.837          0.000000    0.0752   0.8700  73.728
# 52570       0.1480         0.837          0.000000    0.0752   0.8700  73.728
# 16919       0.0356         0.976          0.498000    0.1510   0.6850  88.180
# 16719       0.0356         0.976          0.498000    0.1510   0.6850  88.180
#
#        time_signature track_genre
# 52714               4  honky-tonk
# 52766               4  honky-tonk
# 39307               4      german
# 39275               4      german
# 16747               4   classical
# ...               ...         ...
# 17891               4        club
# 52520               4  honky-tonk
# 52570               4  honky-tonk
# 16919               3   classical
# 16719               3   classical
#
# [627 rows x 20 columns]

# %%
df_genres = df[df['track_genre'].isin(['pop','folk','emo','punk-rock', 'electronic'])]
df_sample = df_genres.sample(n=4000, random_state=1)
# Out:
#                      track_id                       artists  \
# 2106   003vvx7Niy0yvhvHt4a68B                   The Killers
# 3257   003vvx7Niy0yvhvHt4a68B                   The Killers
# 35138  006rHBBNLJMpQs8fRC2GDe  Calcinha Preta;Gusttavo Lima
# 77391  006rHBBNLJMpQs8fRC2GDe  Calcinha Preta;Gusttavo Lima
# 62346  006tmNZLXEXPqdb23wwSN1                    İlhan İrem
# ...                       ...                           ...
# 67285  7zubR9uYAWjb5KPZTMm85e               Jhayco;Anuel AA
# 72679  7zv2vmZq8OjS54BxFzI2wM                        Attila
# 22326  7zv2vmZq8OjS54BxFzI2wM                        Attila
# 2004   7zwn1eykZtZ5LODrf7c0tS             The Neighbourhood
# 3100   7zwn1eykZtZ5LODrf7c0tS             The Neighbourhood
#
#                                             album_name  \
# 2106                                          Hot Fuss
# 3257                                          Hot Fuss
# 35138                  CP 25 Anos (Ao Vivo em Aracaju)
# 77391                  CP 25 Anos (Ao Vivo em Aracaju)
# 62346                        Bezginin Gizli Mektupları
# ...                                                ...
# 67285                           El perreo es el futuro
# 72679                    Soundtrack to a Party (Bonus)
# 22326                    Soundtrack to a Party (Bonus)
# 2004   Hard To Imagine The Neighbourhood Ever Changing
# 3100   Hard To Imagine The Neighbourhood Ever Changing
#
#                            track_name  popularity  duration_ms  explicit  \
# 2106                   Mr. Brightside          86       222973     False
# 3257                   Mr. Brightside          86       222973     False
# 35138  Agora Estou Sofrendo - Ao Vivo          47       260510     False
# 77391  Agora Estou Sofrendo - Ao Vivo          47       260510     False
# 62346              Yemyeşil Bir Deniz          44       358173     False
# ...                               ...         ...          ...       ...
# 67285                        Ley Seca           0       263666     False
# 72679            Lets Start the Party          25       125859      True
# 22326            Lets Start the Party          25       125859      True
# 2004               You Get Me So High          83       153000     False
# 3100               You Get Me So High          83       153000     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 2106          0.352   0.911    1    -5.230     1       0.0747      0.001210
# 3257          0.352   0.911    1    -5.230     1       0.0747      0.001210
# 35138         0.605   0.678    0    -3.257     1       0.0311      0.642000
# 77391         0.605   0.678    0    -3.257     1       0.0311      0.642000
# 62346         0.486   0.568    9    -9.199     0       0.0417      0.652000
# ...             ...     ...  ...       ...   ...          ...           ...
# 67285         0.759   0.843    8    -3.718     1       0.0913      0.127000
# 72679         0.592   0.932    1    -5.412     1       0.0558      0.000005
# 22326         0.592   0.932    1    -5.412     1       0.0558      0.000005
# 2004          0.551   0.881    7    -6.099     0       0.0542      0.186000
# 3100          0.551   0.881    7    -6.099     0       0.0542      0.186000
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 2106             0.0000    0.0995    0.236  148.033               4
# 3257             0.0000    0.0995    0.236  148.033               4
# 35138            0.0000    0.1570    0.439  125.059               4
# 77391            0.0000    0.1570    0.439  125.059               4
# 62346            0.0000    0.8340    0.650  127.184               4
# ...                 ...       ...      ...      ...             ...
# 67285            0.0000    0.1140    0.560  105.016               4
# 72679            0.8590    0.0730    0.677  133.987               4
# 22326            0.8590    0.0730    0.677  133.987               4
# 2004             0.0791    0.1520    0.387   88.036               4
# 3100             0.0791    0.1520    0.387   88.036               4
#
#        track_genre
# 2106      alt-rock
# 3257   alternative
# 35138        forro
# 77391       pagode
# 62346        j-pop
# ...            ...
# 67285        latin
# 72679    metalcore
# 22326  death-metal
# 2004      alt-rock
# 3100   alternative
#
# [22582 rows x 20 columns]

# %%
df['artists'].value_counts()
# Out:
# artists
# George Jones                                    271
# Linkin Park                                     224
# Ella Fitzgerald                                 222
# my little airport                               171
# Stevie Wonder                                   159
#                                                ...
# Ryuichi Sakamoto;alva noto                        1
# Poemme                                            1
# Ólafur Arnalds;Reykjavík Recording Orchestra      1
# Turma do Pagode;Gaab;Rodriguinho;Mr. Dan          1
# Turma do Pagode;MC Hariel                         1
# Name: count, Length: 22824, dtype: int64

# %%
df.describe()
# Out:
#          popularity   duration_ms  danceability        energy           key  \
# count  77911.000000  7.791100e+04  77911.000000  77911.000000  77911.000000
# mean      32.535342  2.324978e+05      0.564312      0.653365      5.312818
# std       22.219178  1.142327e+05      0.176860      0.252007      3.553085
# min        0.000000  0.000000e+00      0.000000      0.000020      0.000000
# 25%       16.000000  1.769330e+05      0.449000      0.486000      2.000000
# 50%       32.000000  2.164260e+05      0.575000      0.700000      5.000000
# 75%       50.000000  2.669515e+05      0.696000      0.867000      8.000000
# max      100.000000  5.237295e+06      0.984000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  77911.000000  77911.000000  77911.000000  77911.000000
# mean      -8.095174      0.632337      0.090250      0.294785
# std        4.941487      0.482172      0.117432      0.329775
# min      -42.044000      0.000000      0.000000      0.000000
# 25%       -9.859000      0.000000      0.036300      0.010700
# 50%       -6.826000      1.000000      0.050300      0.135000
# 75%       -4.861000      1.000000      0.089900      0.560000
# max        4.532000      1.000000      0.965000      0.996000
#
#        instrumentalness      liveness       valence         tempo  \
# count      77911.000000  77911.000000  77911.000000  77911.000000
# mean           0.169227      0.210352      0.456357    122.647867
# std            0.318466      0.185879      0.255087     29.568453
# min            0.000000      0.011200      0.000000      0.000000
# 25%            0.000000      0.097300      0.243000     99.985000
# 50%            0.000078      0.131000      0.439000    122.518000
# 75%            0.095850      0.271000      0.659000    140.361500
# max            0.999000      1.000000      0.995000    243.372000
#
#        time_signature
# count    77911.000000
# mean         3.910963
# std          0.414215
# min          0.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          5.000000

# %%
df['danceability'].hist(bins=60)
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['danceability'])
# Out:
# <Axes: xlabel='danceability'>

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
df_corr = df[['popularity',
       'duration_ms', 'danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'time_signature']].corr()
df_corr
# Out:
#                   popularity  duration_ms  danceability    energy       key  \
# popularity          1.000000    -0.028105      0.039449  0.006107  0.001408
# duration_ms        -0.028105     1.000000     -0.085741  0.043542  0.010162
# danceability        0.039449    -0.085741      1.000000  0.101138  0.036880
# energy              0.006107     0.043542      0.101138  1.000000  0.050136
# key                 0.001408     0.010162      0.036880  0.050136  1.000000
# loudness            0.094415    -0.029170      0.215372  0.785626  0.040777
# mode               -0.025007    -0.037321     -0.069475 -0.101835 -0.142770
# speechiness        -0.047999    -0.060519      0.097413  0.152055  0.014577
# acousticness       -0.017756    -0.086602     -0.154940 -0.749015 -0.045104
# instrumentalness   -0.142961     0.142969     -0.198979 -0.180403 -0.004801
# liveness           -0.010051     0.012793     -0.119660  0.182455 -0.001064
# valence            -0.022437    -0.153374      0.494521  0.219920  0.037089
# tempo               0.019248     0.024053     -0.068434  0.243413  0.009335
# time_signature      0.035960     0.009017      0.174346  0.163509  0.017251
#
#                   loudness      mode  speechiness  acousticness  \
# popularity        0.094415 -0.025007    -0.047999     -0.017756
# duration_ms      -0.029170 -0.037321    -0.060519     -0.086602
# danceability      0.215372 -0.069475     0.097413     -0.154940
# energy            0.785626 -0.101835     0.152055     -0.749015
# key               0.040777 -0.142770     0.014577     -0.045104
# loudness          1.000000 -0.055756     0.056564     -0.619893
# mode             -0.055756  1.000000    -0.039365      0.124389
# speechiness       0.056564 -0.039365     1.000000      0.014762
# acousticness     -0.619893  0.124389     0.014762      1.000000
# instrumentalness -0.429454 -0.043118    -0.108308      0.109408
# liveness          0.088182  0.013736     0.260627     -0.014613
# valence           0.242636  0.013880     0.035930     -0.099121
# tempo             0.204546 -0.010544    -0.004999     -0.212173
# time_signature    0.170926 -0.022845    -0.024186     -0.180833
#
#                   instrumentalness  liveness   valence     tempo  \
# popularity               -0.142961 -0.010051 -0.022437  0.019248
# duration_ms               0.142969  0.012793 -0.153374  0.024053
# danceability             -0.198979 -0.119660  0.494521 -0.068434
# energy                   -0.180403  0.182455  0.219920  0.243413
# key                      -0.004801 -0.001064  0.037089  0.009335
# loudness                 -0.429454  0.088182  0.242636  0.204546
# mode                     -0.043118  0.013736  0.013880 -0.010544
# speechiness              -0.108308  0.260627  0.035930 -0.004999
# acousticness              0.109408 -0.014613 -0.099121 -0.212173
# instrumentalness          1.000000 -0.096779 -0.300727 -0.033291
# liveness                 -0.096779  1.000000  0.017170  0.009361
# valence                  -0.300727  0.017170  1.000000  0.051747
# tempo                    -0.033291  0.009361  0.051747  1.000000
# time_signature           -0.076486 -0.014297  0.115125  0.027981
#
#                   time_signature
# popularity              0.035960
# duration_ms             0.009017
# danceability            0.174346
# energy                  0.163509
# key                     0.017251
# loudness                0.170926
# mode                   -0.022845
# speechiness            -0.024186
# acousticness           -0.180833
# instrumentalness       -0.076486
# liveness               -0.014297
# valence                 0.115125
# tempo                   0.027981
# time_signature          1.000000

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(df_corr, annot=True, cmap='mako')
# Out:
# <Axes: >

# %%
sns.pairplot(df[['acousticness', 'energy']], height=5, aspect=1.5)

# %%
df_sample = df[['acousticness', 'energy']].sample(n=5000)
sns.pairplot(df_sample, height=5, aspect=1.5, diag_kind='kde')

# %%
df['track_genre'].value_counts()
# Out:
# track_genre
# acoustic          1000
# afrobeat          1000
# alt-rock          1000
# alternative       1000
# ambient           1000
#                   ...
# minimal-techno    1000
# mpb               1000
# new-age           1000
# opera             1000
# pagode             910
# Name: count, Length: 78, dtype: int64

# %%
df_genres = df[df['track_genre'].isin(['pop','folk','emo','punk-rock', 'electronic'])]

# %%
df_sample = df_genres.sample(n=5000, random_state=1, replace=True)

# %%
sns.pairplot(df_sample[['acousticness', 'energy', 'track_genre']], height=5, aspect=1.5, diag_kind='kde', hue='track_genre')
